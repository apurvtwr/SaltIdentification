# %% [markdown]
# ## Visualisation Notebook
# This is where we will do all the data visualisation.

# %%
import pandas as pd

# %%
pd.read_csv('depths.csv')
# Out:
#                id    z
# 0      4ac19fb269  306
# 1      1825fadf99  157
# 2      f59821d067  305
# 3      5b435fad9d  503
# 4      e340e7bfca  783
# 5      2ffea0c397  429
# 6      6cf284fb9e  600
# 7      d0244d6c38   51
# 8      cffbfab33b  755
# 9      e82421363e   68
# 10     9090f8f97b  253
# 11     778a92f420  476
# 12     57e394bc67  765
# 13     1efe1909ed  143
# 14     8d89d465fc  529
# 15     211fc910da  336
# 16     b12a5a2b61  475
# 17     28948eeb9c  306
# 18     28f6f52c8f  317
# 19     211eb21702  188
# 20     4ee5d2c629  421
# 21     fe9e558605  535
# 22     ac1ea6faa4  635
# 23     380ff30e30  892
# 24     99d7f0c538  500
# 25     c3589905df  236
# 26     16e308dbc3  313
# 27     48bb098115  649
# 28     07ac7e530f  638
# 29     6c4568e51c  364
# ...           ...  ...
# 21970  5a8b4aeb28  768
# 21971  c8a0a0c511  339
# 21972  52889bff06  503
# 21973  7f76751c6b  508
# 21974  47c58dfdae  583
# 21975  d155b45b62  529
# 21976  82b62ee3be  398
# 21977  16da227a77  463
# ...
